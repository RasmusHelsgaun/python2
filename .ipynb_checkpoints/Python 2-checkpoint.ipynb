# %% [markdown]
# # 1. Create a bar plot that shows distribution of german and british citizens in terms of age.

# %%
# %matplotlib notebook
import kkdata
import matplotlib.pyplot as plt
import cit

germany = 5180
britain = 5170
countries = [germany, britain]
age_dist = cit.get_citizen_dist_age(countries)
print(age_dist)

plt.figure()
title = 'Distribution of German and British citizens by age in {}'.format(2015)
plt.title(title, fontsize=12)
plt.xlabel("Ages", fontsize=10)
plt.ylabel("Amount", fontsize=10)

x_germany = age_dist[5180].keys()
y_germany = age_dist[5180].values()
plt.bar(x_germany, y_germany, width=0.5, linewidth=0, align='center', color='red')

x_britain = age_dist[5170].keys()
y_britain = age_dist[5170].values()
plt.bar(x_britain, y_britain, width=0.5, linewidth=0, align='center', color='blue')
# Out:
# {5170: {0: 24, 1: 37, 2: 25, 3: 30, 4: 32, 5: 20, 6: 17, 7: 24, 8: 12, 10: 18, 11: 14, 12: 20, 13: 17, 14: 13, 15: 17, 16: 26, 17: 21, 18: 26, 19: 41, 20: 82, 21: 94, 22: 83, 23: 107, 24: 109, 25: 105, 26: 129, 27: 120, 28: 121, 29: 120, 30: 135, 31: 114, 32: 100, 33: 105, 34: 104, 35: 110, 36: 101, 37: 87, 38: 110, 39: 92, 40: 92, 41: 99, 42: 108, 43: 85, 44: 86, 45: 82, 46: 83, 47: 74, 48: 79, 49: 77, 50: 73, 51: 80, 52: 73, 53: 59, 54: 61, 55: 50, 56: 52, 57: 46, 58: 38, 59: 51, 60: 33, 61: 38, 62: 47, 63: 45, 64: 29, 65: 33, 66: 26, 67: 29, 68: 24, 69: 21, 70: 25, 71: 21, 73: 10, 74: 10, 75: 21, 76: 14, 77: 8, 78: 6, 79: 11, 80: 4, 81: 4, 82: 7, 88: 4, 90: 4, 91: 1, 9: 13, 72: 13, 83: 5, 85: 2, 87: 2, 84: 1, 89: 1, 86: 1}, 5180: {0: 35, 1: 39, 2: 20, 3: 24, 4: 13, 5: 24, 6: 21, 7: 15, 8: 11, 9: 14, 10: 11, 12: 10, 14: 10, 15: 8, 17: 11, 18: 9, 19: 12, 20: 41, 21: 75, 22: 91, 23: 150, 24: 202, 25: 252, 26: 213, 27: 205, 28: 199, 29: 168, 30: 135, 31: 155, 32: 131, 33: 139, 34: 110
# ...

# %% [markdown]
# # 2. How many French are there compared to Germans and how are they distributed over various neighbourhoods?

# %%
# %matplotlib notebook
import kkdata
import matplotlib.pyplot as plt
import cit

germany = 5180
france = 5130
countries = [germany, france]

total = cit.get_citizen_dist_total(countries)
print("Total distribution:", total)

plt.figure()
title = 'Total distribution of French and German citizens by area in {}'.format(2015)
plt.title(title, fontsize=12)
plt.xlabel("Area", fontsize=10)
plt.ylabel("Amount", fontsize=10)

x_total = total.keys()
y_total = total.values()
plt.bar(x_total, y_total, width=10, align='center')
# Out:
# Total distribution: {5130: 2156, 5180: 4021}
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 2 artists>

# %%
# %matplotlib notebook
import kkdata
import matplotlib.pyplot as plt
import cit

germany = 5180
france = 5130
countries = [germany, france]

dist = cit.get_citizen_dist_area(countries)
print("Distribution per area:", dist)

plt.figure()
title = 'Distribution of French and German citizens by area in {}'.format(2015)
plt.title(title, fontsize=12)
plt.xlabel("Area", fontsize=10)
plt.ylabel("Amount", fontsize=10)

x_germany = dist[germany].keys()
y_germany = dist[germany].values()
plt.bar(x_germany, y_germany, width=0.5, linewidth=0, align='center', color='red')

x_france = dist[france].keys()
y_france = dist[france].values()
plt.bar(x_france, y_france, width=0.5, linewidth=0, align='center', color='blue')
# Out:
# Distribution per area: {5130: {1: 346, 2: 337, 3: 305, 4: 325, 5: 133, 6: 85, 7: 65, 8: 135, 9: 155, 10: 243, 99: 27}, 5180: {1: 544, 2: 557, 3: 653, 4: 474, 5: 258, 6: 166, 7: 197, 8: 314, 9: 372, 10: 460, 99: 26}}
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 11 artists>

# %% [markdown]
# # 3. Create a pie chart showing the 5 major citizen groups of age between 20-65

# %%
# %matplotlib notebook
import kkdata
import matplotlib.pyplot as plt
import cit

top_5 = cit.get_top_5()
print("Top 5 citizen groups: ", top_5)

labels = []
sizes = []

for country in top_5:
    labels.append(str(country))
    sizes.append(top_5[country])
    
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# Top 5 citizen groups:  {5120: 4054, 5170: 3801, 5110: 3592, 5180: 3574, 5154: 3334}
# <img src="data:image/png;base64,..." width="640">
